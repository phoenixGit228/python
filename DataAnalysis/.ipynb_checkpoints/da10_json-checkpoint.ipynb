# %%
import json

# %%
with open('cookie.json',mode='r',encoding='utf-8') as f:
    f_read = f.read()

# %%
data = json.loads(f_read)

# %%
data
# Out:
# [{'domain': '.bilibili.com',
#   'expirationDate': 1623857403,
#   'hostOnly': False,
#   'httpOnly': False,
#   'name': '_uuid',
#   'path': '/',
#   'sameSite': 'unspecified',
#   'secure': False,
#   'session': False,
#   'storeId': '0',
#   'value': 'C502EA8E-2FE7-79FE-186A-795033A8B6C703104infoc',
#   'id': 1},
#  {'domain': '.bilibili.com',
#   'expirationDate': 1607872882.679216,
#   'hostOnly': False,
#   'httpOnly': False,
#   'name': 'bili_jct',
#   'path': '/',
#   'sameSite': 'unspecified',
#   'secure': False,
#   'session': False,
#   'storeId': '0',
#   'value': 'a5a5e70856a6be314771b67d779aa2c2',
#   'id': 2},
#  {'domain': '.bilibili.com',
#   'expirationDate': 1597292801,
#   'hostOnly': False,
#   'httpOnly': False,
#   'name': 'bp_video_offset_8479210',
#   'path': '/',
#   'sameSite': 'unspecified',
#   'secure': False,
#   'session': False,
#   'storeId': '0',
#   'value': '411723849993310199',
#   'id': 3},
#  {'domain': '.bilibili.com',
#   'expirationDate': 1686929403.250356,
#   'hostOnly': False,
#   'httpOnly': False,
#   'name': 'buvid3',
#   'path': '/',
#   'sameSite': 'unspecified',
#   'secure': False,
#   'session': False,
#   'storeId': '0',
#   'value': '5C0E43A2-E7FF-4713-8D31-09887D432D22155842infoc',
#   'id': 4},
#  {'domain': '.bilibili.com',
#   'expirationDate': 1627266469,
#   'hostOnly': False,
#   'httpOnly': False,
#   'name': 'CURRENT_FNVAL',
#   'path': '/',
#   'sameSite': 'unspecified',
#   'secure': False,
#   'session': False,
#   'storeId': '0',
#   'value': '16',
#   'id': 5},
#  {'domain': '.bilibili.com',
#   'expirationDate': 1624155011,
#   'hostOnly': False,
#   'httpOnly': False,
#   'name': 'CURRENT_QUALITY',
#   'path': '/',
#   'sameSite': 'unspecified',
#   'secure': False,
#   'session': False,
#   'storeId': '0',
#   'value': '80',
#   'id': 6},
#  {'domain': '.bilibili.com',
#   'expirationDate': 1607872882.679052,
#   'hostOnly': False,
#   'httpOnly': False,
#   'name': 'DedeUserID',
#   'path': '/',
#   'sameSite': 'unspecified',
#   'secure': False,
#   'session': False,
#   'storeId': '0',
#   'value': '8479210',
#   'id': 7},
#  {'domain': '.bilibili.com',
#   'expirationDate': 1607872882.679108,
#   'hostOnly': False,
#   'httpOnly': False,
#   'name': 'DedeUserID__ckMd5',
#   'path': '/',
#   'sameSite': 'unspecified',
#   'secure': False,
#   'session': False,
#   'storeId': '0',
#   'value': '5e2c8ba0b7779565',
#   'id': 8},
#  {'domain': '.bilibili.com',
#   'expirationDate': 2177452800.103233,
#   'hostOnly': False,
#   'httpOnly': False,
#   'name': 'LIVE_BUVID',
#   'path': '/',
#   'sameSite': 'unspecified',
#   'secure': False,
#   'session': False,
#   'storeId': '0',
#   'value': 'AUTO5715926227606171',
#   'id': 9},
#  {'domain': '.bilibili.com',
#   'expirationDate': 253402300799,
#   'hostOnly': False,
#   'httpOnly': False,
#   'name': 'PVID',
#   'path': '/',
#   'sameSite': 'unspecified',
#   'secure': False,
#   'session': False,
#   'storeId': '0',
#   'value': '1',
#   'id': 10},
#  {'domain': '.bilibili.com',
#   'expirationDate': 1668121200.877745,
#   'hostOnly': False,
#   'httpOnly': False,
#   'name': 'rpdid',
#   'path': '/',
#   'sameSite': 'unspecified',
#   'secure': False,
#   'session': False,
#   'storeId': '0',
#   'value': "|(u))|mu)u|l0J'ulmkJkuRk~",
#   'id': 11},
#  {'domain': '.bilibili.com',
#   'expirationDate': 1607872882.679161,
#   'hostOnly': False,
#   'httpOnly': True,
#   'name': 'SESSDATA',
#   'path': '/',
#   'sameSite': 'unspecified',
#   'secure': False,
#   'session': False,
#   'storeId': '0',
#   'value': '6ab3e5e3%2C1607873882%2C6f6b4*61',
#   'id': 12},
#  {'domain': '.bilibili.com',
#   'hostOnly': False,
#   'httpOnly': False,
#   'name': 'sid',
#   'path': '/',
#   'sameSite': 'unspecified',
#   'secure': False,
#   'session': True,
#   'storeId': '0',
#   'value': 'j91x6xck',
#   'id': 13},
#  {'domain': 'www.bilibili.com',
#   'hostOnly': True,
#   'httpOnly': False,
#   'name': 'finger',
#   'path': '/video',
#   'sameSite': 'unspecified',
#   'secure': False,
#   'session': True,
#   'storeId': '0',
#   'value': '1571944565',
#   'id': 14}]

# %%
type(data)
# Out:
# list

# %%
data[0]['domain']
# Out:
# '.bilibili.com'

# %%
len(data)
# Out:
# 14

# %%
json_data = data[0]

# %%
with open('cookie.json','w', encoding='utf-8') as f:
    json.dump(json_data, f, indent=0)
